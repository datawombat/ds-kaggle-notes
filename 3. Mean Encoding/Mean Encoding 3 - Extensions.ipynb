# %% [markdown]
# ## Mean encoding on regression tasks
#
# - There are more statistics to use. Percentiles, std, distribution bins.
# - In binary classification, mean would be the only meaningful statistic.
#
# ## Mean encoding on multiclass classification
#
# - Mean encoding here introduces new info about the structure of the classes in one vs all classifiers. (TODO)
#
# ## Mean encoding on domains with many-to-many relations
#
# This is an example of many-to-many relation
#
# many_to_many.png![image.png](attachment:image.png)
#
# There are many apps per user, and each app is used by many users.

# %% [markdown]
# To mean-encode 'apps', we need a cross-product of user and app. This may need to mapped back to the users.
#
# long-representation.png![image.png](attachment:image.png)

# %% [markdown]
# ## Mean encodings on time series
#
# Here, we predict on which categories 'spend' a user spends money.
#
# time-series-mean-encoding.png![image.png](attachment:image.png)
#
# Possible features:
# - Total money spent on the previous day.
# - Average money spent by all users in each category.
#
# I may have to go over this video again.
# https://www.coursera.org/learn/competitive-data-science/lecture/D09Jb/extensions-and-generalizations

# %% [markdown]
# ## Mean encoding on numeric features
#
# In practice, it can be useful. They only have to be binned and be treated as categorical.
#
# Here we can also make numeric features interact by combining them.
#
# 1. Fit a tree based model.
# 2. If the feature has a lot of split points, then it may be useful to bin it and mean-encode it.
#
# **Competitions where feature interaction is useful: Amazon employee access challenge** - Catboost gradient boosting library (TODO)

# %% [markdown]
# ## Mean encoding for submissions
#
# Local experiments:
# - Estimate encodings on X_train
# - Map them to X_train and X_val
# - Regularize on X_train
# - Validate model on X_train/X_val split
#
# During submission:
# - Estimate encodings on whole train data
# - Map them to TRAIN and TEST
# - Regularize in TRAIN
# - Fit on TRAIN
